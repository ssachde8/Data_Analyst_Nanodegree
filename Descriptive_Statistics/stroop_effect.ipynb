# %%
# import all necessary packages and functions.
import csv
from datetime import datetime
import numpy as np
import pandas as pd
from scipy import stats, integrate
from IPython.display import display
# %matplotlib inline
import matplotlib.pyplot as plt

import seaborn as sns
sns.set(color_codes=True)

# %%
# file locations
file_in  = 'stroopdata.csv'

congruent = []
incongruent = []
i = 0
with open(file_in, 'r') as f_in:
    # set up csv reader and writer objects
    in_reader = csv.reader(f_in)
    
    # write rows from in-file to out-file until specified date reached
    while True:
        datarow = next(in_reader)
        congruent.append(datarow[0])
        incongruent.append(datarow[1])
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-71-9f820a2ec65b> in <module>()
#      11     # write rows from in-file to out-file until specified date reached
#      12     while True:
# ---> 13         datarow = next(in_reader)
#      14         congruent.append(datarow[0])
#      15         incongruent.append(datarow[1])
#
# StopIteration:

# %%
data = pd.read_csv('stroopdata.csv')
data_plot = data.plot(kind='bar', stacked=True, title="Stroop Effect Analysis")
data_plot.set_xlabel("Word Number")
data_plot.set_ylabel("Time Taken")

# %%
data.boxplot(return_type='axes')

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002A597B58780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002A5973082E8>]], dtype=object)
