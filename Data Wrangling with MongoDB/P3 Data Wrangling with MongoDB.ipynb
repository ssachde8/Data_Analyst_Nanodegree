# %% [markdown]
# # P3 - Data Wrangling with MongoDB

# %% [markdown]
# ### by Satvik Sachdev

# %% [markdown]
# # Project Summary

# %% [markdown]
# Map Used: Phoenix, Arizona
# Objective:
#     - Work with OpenStreetMap dataset
#     - Assess the quality of the data for validity, accuracy, completeness, consistency and uniformity.
#     - Parse and gather data from popular file formats such as .json, .xml, .csv
#     - Process data from large files
#     - Learn how to store, query, and aggregate data using MongoDB

# %% [markdown]
# # 1. Data Audit

# %% [markdown]
# ### 1.1 Unique Tags

# %% [markdown]
# Task: How to parse the file and find all unique tags?
#
# Challenges:
#     - File size > 2GB
#     - Cannot load entire file into memory.
#     - Therefore, use iterative parser over tree based parser to load one element at a time.
#
# Findings:
#     - Differetnt types of tags
#     - Count of tags
#
# mapparser.py is used count the number of unique tags.

# %%
OSMFILE = 'data/phoenix_osm_dataset'
OSMFILE

# %%
import mapparser
mapparser.count_tags(OSMFILE)

# %% [markdown]
# ### 1.2 Check for Patterns

# %% [markdown]
# Use process_map from tags.py to find any problematic data.

# %%
import tags
tags.process_map(OSMFILE)

# %% [markdown]
# ### 1.3 List all Users

# %% [markdown]
# Task:
#     - Find the number of unique users who have contributed to the dataset
#
# Use process_map from users.py to generate a list of all users who have contributed to the dataset.

# %%
import users
all_users = users.process_map(OSMFILE)
all_users

# %% [markdown]
# # 2. Probelms Encountered

# %% [markdown]
# Overview:
#
# Task:
#         - audit dataset to reflect the changes needed to fix the unexpected street types to the appropriate ones in the expected list.
#         - Create a function to fix the street names.
#
# Challenges:
#     - Multiple errors.
#     - Street names are differently abbreviated leading to inconsistency.
#     - Each user types in things differently.

# %% [markdown]
# ### 2.1 Street Names

# %%
from audit_file import *

# %% [markdown]
# Let's have a look at some of the erroreous data.

# %%
street_data = audit(OSMFILE)

from pprint import pprint
pprint(dict(street_data))
# Out:
# {'100': set(['East Elwood Street Suite 100']),
#  '101': set(['Grand Avenue #101', 'N 27th Ave Ste 101']),
#  '102': set(['North 93rd Avenue #102', 'W Lake Pleasant Pkwy # 102']),
#  '103': set(['E Greenway Pkwy #103']),
#  '105': set(['N Scottsdale Rd #105', 'North 90th Street #105']),
#  '108': set(['W Elliot Rd #108']),
#  '1081': set(['N. 55th Ave #1081']),
#  '110': set(['E 5th Ave #110', 'East Doubletree Ranch Road #110']),
#  '117': set(['N 51st Ave #117']),
#  '120': set(['North 16th Avenue #120']),
#  '133': set(['West Indian School Road #133']),
#  '1400-1532': set(['N. Central Avenue, Suite 1400-1532']),
#  '148': set(['S 48th St #148']),
#  '15935': set(['E Thomas Road #15935']),
#  '170-A': set(['E. Chandler Blvd. #170-A']),
#  '200': set(['East Elwood Street Suite 200',
#              'East Marilyn Road Building 4 Suite 200',
#              'W Union Hills Dr., Building D, Suite 200']),
#  '201': set(['West Ray Road, Suite 201']),
#  '202': set(['N Dysart Rd #202']),
#  '208': set(['N 19th Ave Suite 208']),
#  '21': set(['N 32nd St Lot 21']),
#  '21-577': set(['E. Indian School Road, #21-577']),
#  '210': set(['N. Hayden Road, Suite 210']),
#  '2139': set(['E Camelback Road #2139']),
#  '270': set(['East Washington Street Suite 270']),
#  '3': set(['E Thomas Rd #3']),
#  '300': set(['Doubletree Ranch Rd. Suite 300']),
#  '3031': set(['Tatum Blvd. Suite 3031']),
#  '350': set(['N. 85th Street #350']),
#  '4-239': set(['East McKellips Road #4-239']),
#  '401': set(['North 27th Avenue #401']),
#  '441': set(['N. 19th Avenue, Suite 158, #441']),
#  '445': set(['N. 19th Avenue, Suite 158, #445']),
#  '5': set(['North 51st Avenue Suite #134 Building 5']),
#  '540-132': set(['E. Indian School Road, Suite 540-132']),
#  '605': set(['West Happy Valley Road, Suite #141 - 605']),
#  '900': set(['Rio Salado Parkway #900']),
#  '9400': set(['N Scottsdale Rd #9400']),
#  'A-110': set(['North 28th Drive, Suite A-110']),
#  'A6': set(['S Rural Rd #A6']),
#  'Ave': set(['1701 E Southern Ave',
#              'E Southern Ave',
#              'E Ventura Ave',
#              'N 45th Ave',
#              'N College Ave',
#              'NW Newport Ave',
#              'Noth Central Ave',
#              'S Central Ave',
#              'S Farmer Ave',
#              'South Forest Ave',
#              'W Grand Ave']),
#  'Ave#1515': set(['218 3rd Ave#1515']),
#  'Ave,': set(['McKinney Ave,']),
#  'Ave.': set(['E. Devonshire Ave.', 'N. 19th Ave.']),
#  'B': set(['W. Papago Freeway, Suite B']),
#  'B119': set(['East Pinnacle Peak Road #B119']),
#  'Bend': set(['East Indian Bend']),
#  'Blvd': set(['1900 West Chandler Blvd',
#               'E Chandler Blvd',
#               'E Shea Blvd',
#               'Tatum Blvd']),
#  'Blvd.': set(['Apache Blvd.']),
#  'Boulavard': set(['North Avondale Boulavard']),
#  'Campo': set(['Via Del Campo']),
#  'Center': set(['West Arrowhead Towne Center']),
#  'Circle': set(['South Arizona Mills Circle']),
#  'Commercio': set(['East Via De Commercio']),
#  'Crossing': set(['North Cotton Crossing']),
#  'Ctr': set(['W Arrowhead Towne Ctr']),
#  'D107-108': set(['North 7th Street #D107-108']),
#  'Dobson': set(['South Dobson']),
#  'Dr': set(['E San Salvador Dr',
#             'Laurel Ridge Dr',
#             'N 28th Dr',
#             'W Union Hills Dr']),
#  'Dr.': set(['E. Davenport Dr.']),
#  'E108': set(['W Bell Rd #E108']),
#  'East': set(['North Metro Park East']),
#  'Estrella': set(['East Via Estrella']),
#  'F113': set(['E Pinnacle Peak Rd #F113']),
#  'F6': set(['West Orion Street Suite F6']),
#  'Freeway': set(['West Papago Freeway']),
#  'Glen': set(['North 25th Glen']),
#  'Highway': set(['North Black Canyon Highway', 'West Carefree Highway']),
#  'LN.': set(['W Port AU Prince LN.']),
#  'Longmore': set(['South Longmore']),
#  'Loop': set(['North Greenway Hayden Loop']),
#  'Mall': set(['East Lemon Mall',
#               'East Orange Mall',
#               'East Tyler Mall',
#               'South Cady Mall',
#               'South Forest Mall']),
#  'N7': set(['Orca Street, N7']),
#  'NW': set(['Abbeville Ave NW']),
#  'North': set(['East Paradise Village Parkway North']),
#  'Oro': set(['West Camino de Oro']),
#  'Park': set(['East Gammage Park']),
#  'Parkwway': set(['North Coyote Lakes Parkwway']),
#  'Phoenix': set(['Glendale, Phoenix']),
#  'Pkwy': set(['East Rio Salado Pkwy']),
#  'Plaza': set(['North Civic Center Plaza']),
#  'Point': set(['North Sunrise Point']),
#  'Q102': set(['S Mill Ave #Q102']),
#  'Rd': set(['E Baseline Rd',
#             'Manor Rd',
#             'N Hayden Rd',
#             'N Scottsdale Rd',
#             'W Broadway Rd',
#             'W Camelback Rd']),
#  'Rd.': set(['N. Cave Creek Rd.', 'West Happy Vally Rd.']),
#  'Sol': set(['North Camino del Sol', 'West Camino del Sol']),
#  'South': set(['East Sky Harbor Circle South',
#                'North Paradise Village Parkway South']),
#  'St': set(['W 18th St', 'W McNeil St', 'Washington St']),
#  'St,': set(['N 7th St,', 'S 38th St,', 'Washington St,']),
#  'Sur': set(['North Via Paseo del Sur']),
#  'Sycamore': set(['North Sycamore']),
#  'Valencia': set(['South Valencia']),
#  'Ventura': set(['East Via de Ventura']),
#  'Way': set(['Celebrate Life Way',
#              'East Monterey Way',
#              'East Talking Stick Way',
#              'N Marshall Way',
#              'North 102nd Way',
#              'North 22nd Way',
#              'North 27th Way',
#              'North 32nd Way',
#              'North 43rd Way',
#              'North 48th Way',
#              'North Colonnade Way',
#              'North Marshall Way',
#              'South All American Way',
#              'W Citrus Way',
#              'West Anthem Way',
#              'West Celebrate Life Way',
#              'West Mariners Way',
#              'West One Payment Way',
#              'West Walden Way']),
#  'West': set(['North Paradise Village Parkway West'])}

# %% [markdown]
# Now, I will try to update the names using the mapping created inside audit_file to fix the erroneous data.

# %%
for street_type, ways in street_data.iteritems():
    for name in ways:
        better_name = update_name(name, mapping)
        print name, "=>", better_name
# Out:
# East Pinnacle Peak Road #B119 => East Pinnacle Peak Road #B119
# N. Hayden Road, Suite 210 => N. Hayden Road, Suite 210
# 218 3rd Ave#1515 => 218 3rd Ave#1515
# West Indian School Road #133 => West Indian School Road #133
# N 32nd St Lot 21 => N 32nd Street Lot 21
# North 27th Avenue #401 => North 27th Avenue #401
# E Thomas Road #15935 => E Thomas Road #15935
# N. Central Avenue, Suite 1400-1532 => N. Central Avenue, Suite 1400-1532
# East Rio Salado Pkwy => East Rio Salado Parkway
# North 16th Avenue #120 => North 16th Avenue #120
# W Broadway Rd => W Broadway Road
# N Scottsdale Rd => N Scottsdale Road
# N Hayden Rd => N Hayden Road
# W Camelback Rd => W Camelback Road
# Manor Rd => Manor Road
# E Baseline Rd => E Baseline Road
# North Coyote Lakes Parkwway => North Coyote Lakes Parkwway
# Tatum Blvd. Suite 3031 => Tatum Blvd. Suite 3031
# North 28th Drive, Suite A-110 => North 28th Drive, Suite A-110
# North 25th Glen => North 25th Glen
# N. 55th Ave #1081 => N. 55th Avenue #1081
# North Paradise Village Parkway West => North Paradise Village Parkway West
# East Washington Street Suite 270 => East Washington Street Suite 270
# N 51st Ave #117 => N 51st Avenue #117
# East Doubletree Ranch Road #110 => East Doubletree Ranch Road #110
# E 5th Ave #110 => E 5th Avenue #110
# E. Davenport Dr. => E. Davenport Dr.
# South Arizona Mills Circle => South Arizona Mills Circle
# N. Cave Creek Rd. => N. Cave Creek Road
# West Happy Vally Rd. => West Happy Vally Road
# East Gammage Park => East Gammage Park
# West Camino de Oro => West Camino de Oro
# E Thomas Rd #3 => E Thomas Road #3
# E Pinnacle Peak Rd #F113 => E Pinnacle Peak Road #F113
# N. 19th Ave. => N. 19th Ave.
# E. Devonshire Ave. => E. Devonshire Ave.
# McKinney Ave, => McKinney Ave,
# Via Del Campo => Via Del Campo
# Doubletree Ranch Rd. Suite 300 => Doubletree Ranch Road Suite 300
# N. 19th Avenue, Suite 158, #441 => N. 19th Avenue, Suite 158, #441
# North Civic Center Plaza => North Civic Center Plaza
# East McKellips Road #4-239 => East McKellips Road #4-239
# N. 19th Avenue, Suite 158, #445 => N. 19th Avenue, Suite 158, #445
# W Elliot Rd #108 => W Elliot Road #108
# W Lake Pleasant Pkwy # 102 => W Lake Pleasant Parkway # 102
# North 93rd Avenue #102 => North 93rd Avenue #102
# E Greenway Pkwy #103 => E Greenway Parkway #103
# East Elwood Street Suite 100 => East Elwood Street Suite 100
# Grand Avenue #101 => Grand Avenue #101
# N 27th Ave Ste 101 => N 27th Avenue Ste 101
# North Greenway Hayden Loop => North Greenway Hayden Loop
# N Scottsdale Rd #105 => N Scottsdale Road #105
# North 90th Street #105 => North 90th Street #105
# Rio Salado Parkway #900 => Rio Salado Parkway #900
# North Sunrise Point => North Sunrise Point
# East Tyler Mall => East Tyler Mall
# East Lemon Mall => East Lemon Mall
# South Forest Mall => South Forest Mall
# South Cady Mall => South Cady Mall
# East Orange Mall => East Orange Mall
# E. Indian School Road, Suite 540-132 => E. Indian School Road, Suite 540-132
# Washington St, => Washington St,
# S 38th St, => S 38th St,
# N 7th St, => N 7th St,
# S Mill Ave #Q102 => S Mill Avenue #Q102
# West Celebrate Life Way => West Celebrate Life Way
# North Colonnade Way => North Colonnade Way
# West One Payment Way => West One Payment Way
# North 102nd Way => North 102nd Way
# North 32nd Way => North 32nd Way
# North Marshall Way => North Marshall Way
# South All American Way => South All American Way
# East Monterey Way => East Monterey Way
# North 43rd Way => North 43rd Way
# Celebrate Life Way => Celebrate Life Way
# North 48th Way => North 48th Way
# W Citrus Way => W Citrus Way
# North 27th Way => North 27th Way
# North 22nd Way => North 22nd Way
# West Walden Way => West Walden Way
# West Mariners Way => West Mariners Way
# West Anthem Way => West Anthem Way
# East Talking Stick Way => East Talking Stick Way
# N Marshall Way => N Marshall Way
# W Bell Rd #E108 => W Bell Road #E108
# East Paradise Village Parkway North => East Paradise Village Parkway North
# N Scottsdale Rd #9400 => N Scottsdale Road #9400
# Apache Blvd. => Apache Blvd.
# Abbeville Ave NW => Abbeville Avenue NW
# W. Papago Freeway, Suite B => W. Papago Freeway, Suite B
# West Arrowhead Towne Center => West Arrowhead Towne Center
# W 18th St => W 18th Street
# W McNeil St => W McNeil Street
# Washington St => Washington Street
# East Via de Ventura => East Via de Ventura
# W Port AU Prince LN. => W Port AU Prince LN.
# Orca Street, N7 => Orca Street, N7
# West Orion Street Suite F6 => West Orion Street Suite F6
# W Grand Ave => W Grand Avenue
# Noth Central Ave => Noth Central Avenue
# NW Newport Ave => NW Newport Avenue
# 1701 E Southern Ave => 1701 E Southern Avenue
# N College Ave => N College Avenue
# E Southern Ave => E Southern Avenue
# S Central Ave => S Central Avenue
# South Forest Ave => South Forest Avenue
# S Farmer Ave => S Farmer Avenue
# E Ventura Ave => E Ventura Avenue
# N 45th Ave => N 45th Avenue
# North Via Paseo del Sur => North Via Paseo del Sur
# West Happy Valley Road, Suite #141 - 605 => West Happy Valley Road, Suite #141 - 605
# South Valencia => South Valencia
# West Carefree Highway => West Carefree Highway
# North Black Canyon Highway => North Black Canyon Highway
# North Metro Park East => North Metro Park East
# Glendale, Phoenix => Glendale, Phoenix
# E Camelback Road #2139 => E Camelback Road #2139
# East Via Estrella => East Via Estrella
# E. Indian School Road, #21-577 => E. Indian School Road, #21-577
# North 51st Avenue Suite #134 Building 5 => North 51st Avenue Suite #134 Building 5
# S Rural Rd #A6 => S Rural Road #A6
# E San Salvador Dr => E San Salvador Drive
# N 28th Dr => N 28th Drive
# W Union Hills Dr => W Union Hills Drive
# Laurel Ridge Dr => Laurel Ridge Drive
# West Ray Road, Suite 201 => West Ray Road, Suite 201
# East Elwood Street Suite 200 => East Elwood Street Suite 200
# W Union Hills Dr., Building D, Suite 200 => W Union Hills Dr., Building D, Suite 200
# East Marilyn Road Building 4 Suite 200 => East Marilyn Road Building 4 Suite 200
# N Dysart Rd #202 => N Dysart Road #202
# W Arrowhead Towne Ctr => W Arrowhead Towne Ctr
# N 19th Ave Suite 208 => N 19th Avenue Suite 208
# North Sycamore => North Sycamore
# S 48th St #148 => S 48th Street #148
# West Papago Freeway => West Papago Freeway
# North Cotton Crossing => North Cotton Crossing
# North Avondale Boulavard => North Avondale Boulavard
# South Longmore => South Longmore
# East Sky Harbor Circle South => East Sky Harbor Circle South
# North Paradise Village Parkway South => North Paradise Village Parkway South
# South Dobson => South Dobson
# East Via De Commercio => East Via De Commercio
# North Camino del Sol => North Camino del Sol
# West Camino del Sol => West Camino del Sol
# E. Chandler Blvd. #170-A => E. Chandler Blvd. #170-A
# North 7th Street #D107-108 => North 7th Street #D107-108
# East Indian Bend => East Indian Bend
# N. 85th Street #350 => N. 85th Street #350
# E Chandler Blvd => E Chandler Boulevard
# E Shea Blvd => E Shea Boulevard
# Tatum Blvd => Tatum Boulevard
# 1900 West Chandler Blvd => 1900 West Chandler Boulevard

# %% [markdown]
# In the above output we can see that we are able to achieve a desrired consistancy to make this data meaningful.

# %% [markdown]
# ### 2.2 Zip Codes

# %%
from audit_file import *

# %%
from pprint import pprint
# zipcode_info = audit_zip(OSMFILE)

pprint(dict(zipcode_info))
# Out:
# {'19': set(['19971']),
#  '21': set(['21013']),
#  '29': set(['29801']),
#  '75': set(['75201']),
#  '8': set(['8']),
#  '82': set(['82158', '82381']),
#  '83': set(['83003']),
#  '85': set(['85003',
#             '85003-1076',
#             '85003-1135',
#             '85003-1333',
#             '85003-1376',
#             '85004',
#             '85004-1118',
#             '85004-1155',
#             'AZ 85255',
#             'AZ 85256',
#             'AZ 85257',
#             'AZ 85281',
#             'AZ 85282',
#             'AZ 85283',
#             'AZ 85301',
#             'AZ 85310',
#             'AZ 85338',
#             'AZ 85339',
#             'AZ 85351',
#             'AZ 85373',
#             'AZ 85374',
#             'AZ 85375',
#             u'AZ 85375 \u200e',
#             'AZ 85383'])}

# %% [markdown]
# After doing some research, I found out that the possible zipcode range is between 85001-86556.
# Looking at the output above, I see many wrong values which need to be fixed.
#
# I have created an update_zip function which fixes the following:
#     - ensures that zipcode ranges in the corrent range
#     - ensures the valid len of the zipcode
#     - ensures that zipcode contains only numbers

# %%
def update_zip(zipcode):
    zipcode.strip()
    if "AZ" in zipcode:
        zipcode = zipcode.replace("AZ", "")
    if len(zipcode) < 5:
        zipcode = None
    if zipcode is not None and len(zipcode) == 5:
        if zipcode < 85001 or zipcode > '86556':
            zipcode = None
    return zipcode

# %%
for street_type, ways in zipcode_info.iteritems():
    for zipcode in ways:
        better_zipcode = update_zip(zipcode)
        print zipcode, "=>", better_zipcode
# Out:
# AZ 85033 =>  85033
# AZ 85015 =>  85015
# AZ 85014 =>  85014
# AZ 85351 =>  85351
# AZ 85050 =>  85050
# AZ 85374 =>  85374
# AZ 85256 =>  85256
# AZ 85255 =>  85255
# AZ 85254 =>  85254
# AZ 85253 =>  85253
# AZ 85018 =>  85018
# AZ 85251 =>  85251
# AZ 85373 =>  85373
# AZ 85034 =>  85034
# AZ 85310 =>  85310
# AZ 85338 =>  85338
# AZ 85339 =>  85339
# AZ 85257 =>  85257
# AZ 85250 =>  85250
# AZ 85375 ‎ =>  85375 ‎
# AZ 85007 =>  85007
# AZ 85004 =>  85004
# AZ 85301 =>  85301
# AZ 85008 =>  85008
# AZ => None
# AZ 85023 =>  85023
# AZ 85226 =>  85226
# AZ 85045 =>  85045
# AZ 85042 =>  85042
# AZ 85375 =>  85375
# AZ 85383 =>  85383
# AZ 85016 =>  85016
# AZ 85281 =>  85281
# AZ 85282 =>  85282
# AZ 85283 =>  85283
# 21013 => 21013
# 19971 => 19971
# 29801 => 29801
# 99501 => None
# 98409 => None
# 98101 => None
# 75201 => 75201
# 8 => None
# 82381 => 82381
# 82158 => 82158
# 83003 => 83003
# 93702 => None
# 92509 => None
# 92127 => None
# 97701 => None
# 85023-2577 => 85023-2577
# 85023-8208 => 85023-8208
# 85392 => 85392
# 85248 => 85248
# 85023-8205 => 85023-8205
# 85032-7702 => 85032-7702
# 85023-8203 => 85023-8203
# 85023-8202 => 85023-8202
# 85023-8201 => 85023-8201
# 85023-8200 => 85023-8200
# 85014-4614 => 85014-4614
# 85023-1403 => 85023-1403
# 85007-1909 => 85007-1909
# 85023-1533 => 85023-1533
# 85023-1439 => 85023-1439
# 85023-1438 => 85023-1438
# 85023-1536 => 85023-1536
# 85007-2101 => 85007-2101
# 85023-1534 => 85023-1534
# 85023-2358 => 85023-2358
# 85301 => 85301
# 85303 => 85303
# 85302 => 85302
# 85305 => 85305
# 85304 => 85304
# 85307 => 85307
# 85306 => 85306
# 85309 => 85309
# 85308 => 85308
# 85260-5518 => 85260-5518
# 85018-8830 => 85018-8830
# 85019 => 85019
# 85018 => 85018
# 85023-2506 => 85023-2506
# 85023-2308 => 85023-2308
# 85003-1135 => 85003-1135
# 85023-2505 => 85023-2505
# 85266 => 85266
# 85284-1103 => 85284-1103
# 85013 => 85013
# 85012 => 85012
# 85015 => 85015
# 85014 => 85014
# 85260 => 85260
# 85016 => 85016
# 85023-2575 => 85023-2575
# 850822 => 850822
# 85023-8206 => 85023-8206
# 85257-1102 => 85257-1102
# 85023-1515 => 85023-1515
# 85023-1354 => 85023-1354
# 85023-1446 => 85023-1446
# 85083 => 85083
# 85023-1444 => 85023-1444
# 85260-1235 => 85260-1235
# 85086 => 85086
# 85023-1443 => 85023-1443
# 85023-1440 => 85023-1440
# 85085 => 85085
# 85023-1520 => 85023-1520
# 85395 => 85395
# 85032-7708 => 85032-7708
# 85023-1448 => 85023-1448
# 85023-1449 => 85023-1449
# 85023-1507 => 85023-1507
# 85310 => 85310
# 85023-2503 => 85023-2503
# 85021-3542 => 85021-3542
# 85023-2516 => 85023-2516
# 85023-1510 => 85023-1510
# 85023-3105 => 85023-3105
# 85004-1873 => 85004-1873
# 85023-2511 => 85023-2511
# 85023-2510 => 85023-2510
# 85083-4311 => 85083-4311
# 85258 => 85258
# 85023-2515 => 85023-2515
# 85023-2514 => 85023-2514
# 85023-2517 => 85023-2517
# 85023-2554 => 85023-2554
# 85253 => 85253
# 85003 => 85003
# 85251 => 85251
# 85250 => 85250
# 85257 => 85257
# 85007 => 85007
# 85004 => 85004
# 85254 => 85254
# 85023-8204 => 85023-8204
# 85023-2556 => 85023-2556
# 85027-9998 => 85027-9998
# 85023-1455 => 85023-1455
# 85021-3516 => 85021-3516
# 85004-1418 => 85004-1418
# 85004-1316 => 85004-1316
# 85023-1451 => 85023-1451
# 85003-1333 => 85003-1333
# 85023-1453 => 85023-1453
# 85023-1452 => 85023-1452
# 85023-1514 => 85023-1514
# 85023-2383 => 85023-2383
# 85023-1516 => 85023-1516
# 85017 => 85017
# 85007-3232 => 85007-3232
# 85023-1511 => 85023-1511
# 85023-1512 => 85023-1512
# 85023-1513 => 85023-1513
# 85037 => 85037
# 85035 => 85035
# 85034 => 85034
# 85033 => 85033
# 85032 => 85032
# 85031 => 85031
# 85023-2610 => 85023-2610
# 85023-2509 => 85023-2509
# 85007-2616 => 85007-2616
# 85323 => 85323
# 85008 => 85008
# 85009 => 85009
# 85023-2638 => 85023-2638
# 85023-2639 => 85023-2639
# 85023-2307 => 85023-2307
# 85023-2641 => 85023-2641
# 85003-1376 => 85003-1376
# 85023-2637 => 85023-2637
# 85023-2528 => 85023-2528
# 85023-2529 => 85023-2529
# 85043 => 85043
# 85023-2507 => 85023-2507
# 85023-1532 => 85023-1532
# 85023-1460 => 85023-1460
# 85023-1461 => 85023-1461
# 85032-7725 => 85032-7725
# 85041 => 85041
# 85023-1542 => 85023-1542
# 85023-1503 => 85023-1503
# 85023-2519 => 85023-2519
# 85310-4002 => 85310-4002
# 85023-1556 => 85023-1556
# 85023-1557 => 85023-1557
# 85023-1519 => 85023-1519
# 85007-2129 => 85007-2129
# 85050-4270 => 85050-4270
# 85023-2534 => 85023-2534
# 85023-1502 => 85023-1502
# 85023-1411 => 85023-1411
# 85023-1410 => 85023-1410
# 85023-1413 => 85023-1413
# 85007-2121 => 85007-2121
# 85007-2126 => 85007-2126
# 85250-6402 => 85250-6402
# 85004-1820 => 85004-1820
# 85023-2560 => 85023-2560
# 85023-2561 => 85023-2561
# 85007-2419 => 85007-2419
# 85023-2564 => 85023-2564
# 85023-2565 => 85023-2565
# 85023-2566 => 85023-2566
# 85023-2568 => 85023-2568
# 85310-4403 => 85310-4403
# 85202 => 85202
# 85007-2309 => 85007-2309
# 85023-2504 => 85023-2504
# 85023-2310 => 85023-2310
# 85023-1458 => 85023-1458
# 85281 => 85281
# 85282 => 85282
# 85283 => 85283
# 85284 => 85284
# 85023-1526 => 85023-1526
# 85286 => 85286
# 85050-4200 => 85050-4200
# 85023-1441 => 85023-1441
# 85023-1416 => 85023-1416
# 85050-4206 => 85050-4206
# 85023-2544 => 85023-2544
# 85023-2668 => 85023-2668
# 85023-2640 => 85023-2640
# 85381 => 85381
# 85383 => 85383
# 85382 => 85382
# 85023-2586 => 85023-2586
# 85050-6105 => 85050-6105
# 85023-1541 => 85023-1541
# 85023-2563 => 85023-2563
# 85020-5329 => 85020-5329
# 85260-6568 => 85260-6568
# 85374 => 85374
# 85375 => 85375
# 85023-1459 => 85023-1459
# 85023-2574 => 85023-2574
# 85022-6509 => 85022-6509
# 85023-3108 => 85023-3108
# 85053-2010 => 85053-2010
# 85023-2666 => 85023-2666
# 85378 => 85378
# 85379 => 85379
# 85023-2661 => 85023-2661
# 85006 => 85006
# 85004-1118 => 85004-1118
# 85201 => 85201
# 85023-1442 => 85023-1442
# 85023-3208 => 85023-3208
# 85003-1076 => 85003-1076
# 85060 => 85060
# 85020-4217 => 85020-4217

# %% [markdown]
# ### 2.3 Prepare data for database insertion

# %% [markdown]
# The following measures need to be done in order to insert data:
#     - Process only "node" and "way" tags
#     - Convert attrbutes of "node" and "ways" into key->value pairs( exceptions: latitude, longitude, created )
#     - convert "addr:" => "address"
#     - ignore tags which just contain ":"
#     - ignore tags which separate type of street.
#
# After applying the abovementioned steps, I will use process_map function to convert thet file from XML into JSON.

# %%
# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET
import pprint
import re
import codecs
import json

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
address_regex = re.compile(r'^addr\:')
street_regex = re.compile(r'^street')

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]


def shape_element(element):
    node = {}
    if element.tag == "node" or element.tag == "way" :
        # YOUR CODE HERE
        node['type'] = element.tag
        # initialize empty address
        address = {}
        # parsing through attributes
        for a in element.attrib:
            if a in CREATED:
                if 'created' not in node:
                    node['created'] = {}
                node['created'][a] = element.get(a)
            elif a in ['lat', 'lon']:
                continue
            else:
                node[a] = element.get(a)
        # populate position
        if 'lat' in element.attrib and 'lon' in element.attrib:
            node['pos'] = [float(element.get('lat')), float(element.get('lon'))]

        # parse second-level tags for nodes
        for e in element:
            # parse second-level tags for ways and populate `node_refs`
            if e.tag == 'nd':
                if 'node_refs' not in node:
                    node['node_refs'] = []
                if 'ref' in e.attrib:
                    node['node_refs'].append(e.get('ref'))

            # throw out not-tag elements and elements without `k` or `v`
            if e.tag != 'tag' or 'k' not in e.attrib or 'v' not in e.attrib:
                continue
            key = e.get('k')
            val = e.get('v')

            # skip problematic characters
            if problemchars.search(key):
                continue

            # parse address k-v pairs
            elif address_regex.search(key):
                key = key.replace('addr:', '')
                address[key] = val

            # catch-all
            else:
                node[key] = val
        # compile address
        if len(address) > 0:
            node['address'] = {}
            street_full = None
            street_dict = {}
            street_format = ['prefix', 'name', 'type']
            # parse through address objects
            for key in address:
                val = address[key]
                if street_regex.search(key):
                    if key == 'street':
                        street_full = val
                    elif 'street:' in key:
                        street_dict[key.replace('street:', '')] = val
                else:
                    node['address'][key] = val
            # assign street_full or fallback to compile street dict
            if street_full:
                node['address']['street'] = street_full
            elif len(street_dict) > 0:
                node['address']['street'] = ' '.join([street_dict[key] for key in street_format])
        return node
    else:
        return None


def process_map(file_in, pretty = False):
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

data = process_map(OSMFILE, False)

# %% [markdown]
# # 3. Data Overview with MongoDB

# %% [markdown]
# ## Import Data

# %%
from pymongo import MongoClient

db_name = 'map'

# Connect to Mongo DB
client = MongoClient("mongodb://localhost:27017")
db = client[db_name]

# %%
phoenix = db['map']
phoenix
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'map'), u'map')

# %% [markdown]
# File Size

# %%
import os

# %%
 # convert from bytes to megabytes
print 'Original OSM file is {} MB'.format(os.path.getsize(data)/1.0e6)

# convert from bytes to megabytes
print 'New JSON file is {} MB'.format(os.path.getsize(data + ".json")/1.0e6)
# Out:
# Original OSM file is 396.415019 MB
# New JSON file is 442.342844 MB

# %% [markdown]
# ### 3.1 Number of Documents

# %%
print "Total Number of Documents: {}".format(db['map'].find().count())
# Out:
# Total Number of Documents: 1896364

# %% [markdown]
# ### 3.2 Number of Nodes

# %%
print "Number of nodes:",phoenix.find({'type':'node'}).count()
# Out:
# Number of nodes: 1661886

# %% [markdown]
# ### 3.3 Number of ways

# %%
print "Number of ways:", phoenix.find({'type':'way'}).count()
# Out:
# Number of ways: 234412

# %% [markdown]
# ### 3.4 Number of Unique Users

# %%
len(phoenix.distinct("created.user"))
# Out:
# 1022

# %% [markdown]
# ### 3.5 Top 5 Contributors

# %%
from pprint import pprint
result = phoenix.aggregate( [
                            { "$group" : {"_id" : "$created.user", "count" : { "$sum" : 1} } },
                            { "$sort" : {"count" : -1} }, 
                            { "$limit" : 5 } ] )

pprint(list(result))
# Out:
# [{u'_id': u'Dr Kludge', u'count': 894474},
#  {u'_id': u'TheDutchMan13', u'count': 231185},
#  {u'_id': u'Adam Martin', u'count': 155409},
#  {u'_id': u'namannik', u'count': 40850},
#  {u'_id': u'kghazi', u'count': 37019}]

# %% [markdown]
# ### 3.6 Number of Cafes in Phoenix

# %%
phoenix.find({'amenity': "cafe"}).count()
# Out:
# 131

# %% [markdown]
# # 4. Further Data Exploration with MongoDB

# %% [markdown]
# ### 4.1 Users with only 1 entry

# %%
users = phoenix.aggregate( [
        { "$group" : {"_id" : "$created.user", "count" : { "$sum" : 1} } },
        { "$group" : {"_id" : "$count", "num_users": { "$sum" : 1} } },
        { "$sort" : {"_id" : 1} },
        { "$limit" : 1} ] )
pprint(list(users))
# Out:
# [{u'_id': 1, u'num_users': 234}]

# %% [markdown]
# ### 4.2 Top 10 cuisines enjoyed in Phoenix

# %%
cuisine = phoenix.aggregate([
                        {"$match":{"amenity":{"$exists":1}, "amenity":"restaurant",}},      
                        {"$group":{"_id":{"Food":"$cuisine"}, "count":{"$sum":1}}},
                        {"$project":{"_id":0, "Food":"$_id.Food", "Count":"$count"}},
                        {"$sort":{"Count":-1}}, 
                        {"$limit":11}
                    ])
pprint(list(cuisine))
# Out:
# [{u'Count': 318, u'Food': None},
#  {u'Count': 59, u'Food': u'mexican'},
#  {u'Count': 38, u'Food': u'pizza'},
#  {u'Count': 33, u'Food': u'american'},
#  {u'Count': 22, u'Food': u'italian'},
#  {u'Count': 20, u'Food': u'sandwich'},
#  {u'Count': 20, u'Food': u'burger'},
#  {u'Count': 17, u'Food': u'chinese'},
#  {u'Count': 9, u'Food': u'regional'},
#  {u'Count': 7, u'Food': u'sushi'},
#  {u'Count': 7, u'Food': u'steak_house'}]

# %% [markdown]
# ### 4.3 Top buildings

# %%
buildings = phoenix.aggregate([
                        {"$match": {'building': {"$exists": 1}}}, 
                        {"$group": {'_id': '$building', 'count': {"$sum": 1}}}, 
                        {"$sort": {'count': -1}}, 
                        {"$limit": 6}
                    ])
pprint(list(buildings))
# Out:
# [{u'_id': u'yes', u'count': 25047},
#  {u'_id': u'house', u'count': 7399},
#  {u'_id': u'roof', u'count': 3691},
#  {u'_id': u'apartments', u'count': 2209},
#  {u'_id': u'commercial', u'count': 1932},
#  {u'_id': u'residential', u'count': 1573}]

# %% [markdown]
# ### 4.4 Top Amenities

# %%
amenities = phoenix.aggregate([
                        {"$match": {'amenity': {"$exists": 1}}}, 
                        {"$group": {'_id': '$amenity', 'count': {"$sum": 1}}}, 
                        {"$sort": {'count': -1}}, 
                        {"$limit": 6}
                    ])
pprint(list(amenities))
# Out:
# [{u'_id': u'parking', u'count': 3204},
#  {u'_id': u'fast_food', u'count': 779},
#  {u'_id': u'school', u'count': 772},
#  {u'_id': u'place_of_worship', u'count': 747},
#  {u'_id': u'restaurant', u'count': 646},
#  {u'_id': u'fuel', u'count': 570}]

# %% [markdown]
# # 5.Conclusion

# %% [markdown]
# Improvement Ideas:
#     - During data auditing phase, it was clear that data comprises of several errors. A common platform
#     can be provided to make the data entry process smoother. With a platform, minor errors such as
#     having alphabets in numeric zipcodes can be programmatically avoided. By fillig up a form on a platform
#     the user can be given guidance on what data to be filled.
#     - The map contains information about businesses. One future application could be to
#     add another tag to such places in order to describe the type of business.
#     - In order to collect momre information, games and tresure hunt like activities can be done. This way
#     society can combine and get together to enhance the quality and quantity of data.
#
# Problems attached:
#     - The overhead for creating a platform is a lot. It may require the overhaul of the existing methodology.
#     - The cost associated with organising events could be a hindrance.
#     - Manual labor is required to compltete the existing missing data for entries.
#
# Benefits:
#     - With more data, new patterns and insights can be generated.
